# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
transaction_df=pd.read_excel('C:/Users/ASUS/Desktop/KPMG.xlsx','Transactions')

# %%
transaction_df.head()
# Out:
#   Note: The data and information in this document is reflective of a hypothetical situation and client. This document is to be used for KPMG Virtual Internship purposes only.   \
# 0                                     transaction_id
# 1                                                  1
# 2                                                  2
# 3                                                  3
# 4                                                  4
#
#    Unnamed: 1   Unnamed: 2           Unnamed: 3    Unnamed: 4    Unnamed: 5  \
# 0  product_id  customer_id     transaction_date  online_order  order_status
# 1           2         2950  2017-02-25 00:00:00         False      Approved
# 2           3         3120  2017-05-21 00:00:00          True      Approved
# 3          37          402  2017-10-16 00:00:00         False      Approved
# 4          88         3135  2017-08-31 00:00:00         False      Approved
#
# ...

# %%
transaction_df.columns=transaction_df.iloc[0]
transaction_df
# Out:
# 0      transaction_id  product_id  customer_id     transaction_date  \
# 0      transaction_id  product_id  customer_id     transaction_date
# 1                   1           2         2950  2017-02-25 00:00:00
# 2                   2           3         3120  2017-05-21 00:00:00
# 3                   3          37          402  2017-10-16 00:00:00
# 4                   4          88         3135  2017-08-31 00:00:00
# ...               ...         ...          ...                  ...
# 19996           19996          51         1018  2017-06-24 00:00:00
# 19997           19997          41          127  2017-11-09 00:00:00
# 19998           19998          87         2284  2017-04-14 00:00:00
# 19999           19999           6         2764  2017-07-03 00:00:00
# 20000           20000          11         1144  2017-09-22 00:00:00
#
# 0      online_order  order_status           brand  product_line  \
# 0      online_order  order_status           brand  product_line
# ...

# %%
transaction_df.drop(transaction_df.index[0],axis=0,inplace=True)
transaction_df
# Out:
# 0     transaction_id product_id customer_id     transaction_date online_order  \
# 1                  1          2        2950  2017-02-25 00:00:00        False
# 2                  2          3        3120  2017-05-21 00:00:00         True
# 3                  3         37         402  2017-10-16 00:00:00        False
# 4                  4         88        3135  2017-08-31 00:00:00        False
# 5                  5         78         787  2017-10-01 00:00:00         True
# ...              ...        ...         ...                  ...          ...
# 19996          19996         51        1018  2017-06-24 00:00:00         True
# 19997          19997         41         127  2017-11-09 00:00:00         True
# 19998          19998         87        2284  2017-04-14 00:00:00         True
# 19999          19999          6        2764  2017-07-03 00:00:00        False
# 20000          20000         11        1144  2017-09-22 00:00:00         True
#
# ...

# %%
transaction_df.isnull().sum()
# Out:
# 0
# transaction_id               0
# product_id                   0
# customer_id                  0
# transaction_date             0
# online_order               360
# order_status                 0
# brand                      197
# product_line               197
# product_class              197
# product_size               197
# list_price                   0
# standard_cost              197
# product_first_sold_date    197
# dtype: int64

# %%
transaction_df=transaction_df.replace(' ',np.NaN)

# %%
transaction_df['online_order'].value_counts()
# Out:
# online_order
# True     9829
# False    9811
# Name: count, dtype: int64

# %%
for col in transaction_df.columns:
    if transaction_df[col].dtypes=='object':
        transaction_df[col]=transaction_df[col].fillna(transaction_df[col].value_counts().index[0])

# %%
transaction_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 1 to 20000
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transaction_id           20000 non-null  int64
#  1   product_id               20000 non-null  int64
#  2   customer_id              20000 non-null  int64
#  3   transaction_date         20000 non-null  datetime64[ns]
#  4   online_order             20000 non-null  bool
#  5   order_status             20000 non-null  object
#  6   brand                    20000 non-null  object
#  7   product_line             20000 non-null  object
#  8   product_class            20000 non-null  object
#  9   product_size             20000 non-null  object
#  10  list_price               20000 non-null  float64
#  11  standard_cost            20000 non-null  float64
#  12  product_first_sold_date  20000 non-null  int64
# ...

# %%
degraph_df=pd.read_excel('C:/Users/ASUS/Desktop/KPMG.xlsx','CustomerDemographic')

# %%
degraph_df.head()
# Out:
#    customer_id               name gender  past_3_years_bike_related_purchases  \
# 0           34  Jephthah Bachmann      U                                   59
# 1          144    Jory Barrabeale      U                                   71
# 2          168   Reggie Broggetti      U                                    8
# 3          267      Edgar Buckler      U                                   53
# 4          290     Giorgio Kevane      U                                   42
#
#           DOB    age               job_title job_industry_category  \
# 0  1843-12-21    NaN         Legal Assistant                    IT
# 1         NaN  124.0      Environmental Tech                    IT
# 2         NaN  124.0         General Manager                    IT
# 3         NaN  124.0                     NaN                    IT
# 4         NaN  124.0  Senior Sales Associate                    IT
#
#       wealth_segment deceased_indicator owns_car  tenure
# ...

# %%
degraph_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 12 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   customer_id                          4000 non-null   int64
#  1   name                                 4000 non-null   object
#  2   gender                               4000 non-null   object
#  3   past_3_years_bike_related_purchases  4000 non-null   int64
#  4   DOB                                  3913 non-null   object
#  5   age                                  3999 non-null   float64
#  6   job_title                            3494 non-null   object
#  7   job_industry_category                3344 non-null   object
#  8   wealth_segment                       4000 non-null   object
#  9   deceased_indicator                   4000 non-null   object
#  10  owns_car                             4000 non-null   object
# ...

# %%
degraph_df=degraph_df.replace(' ','NaN')

# %%
for col in degraph_df.columns:
    if degraph_df[col].dtypes=='object':
        degraph_df[col]=degraph_df[col].fillna(degraph_df[col].value_counts().index[0])
    elif degraph_df[col].dtypes=='float64':
        degraph_df[col]=degraph_df[col].fillna(degraph_df[col].mean())
        
for i in range(len(df['age’])):
     If int(df['age’][I]) >= 100:
           df['age’][I] = df['age’].mean()

# %%
degraph_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 12 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   customer_id                          4000 non-null   int64
#  1   name                                 4000 non-null   object
#  2   gender                               4000 non-null   object
#  3   past_3_years_bike_related_purchases  4000 non-null   int64
#  4   DOB                                  4000 non-null   object
#  5   age                                  4000 non-null   float64
#  6   job_title                            4000 non-null   object
#  7   job_industry_category                4000 non-null   object
#  8   wealth_segment                       4000 non-null   object
#  9   deceased_indicator                   4000 non-null   object
#  10  owns_car                             4000 non-null   object
# ...

# %%
df1=transaction_df.merge(degraph_df,how='inner',left_on='customer_id',right_on='customer_id').sort_values(['customer_id'])
df1
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 608             16423           9            1       2017-12-09          True
# 609             18970          11            1       2017-03-29          True
# 599                94          86            1       2017-12-23         False
# 600              3765          38            1       2017-04-06          True
# 601              5157          47            1       2017-05-11          True
# ...               ...         ...          ...              ...           ...
# 11304            8416          74         3500       2017-02-16         False
# 11307           19836          40         3500       2017-03-14          True
# 11303            6309          69         3500       2017-01-09          True
# 11302            2463           2         3500       2017-04-25         False
# 11306           14870          22         3500       2017-01-11         False
#
# ...

# %%
df2=df1['customer_id'].value_counts()
df2
# Out:
# customer_id
# 2183    14
# 2476    14
# 1068    14
# 637     13
# 1129    13
#         ..
# 3161     1
# 1387     1
# 161      1
# 1569     1
# 2532     1
# Name: count, Length: 3493, dtype: int64

# %%
df3=df1.merge(df2,how='inner',left_on='customer_id',right_on='customer_id').sort_values(['customer_id'])
df3
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               16423           9            1       2017-12-09          True
# 10               9785          72            1       2017-01-05         False
# 9               13424           2            1       2017-02-21         False
# 7               14486          23            1       2017-03-27         False
# 6               14931          31            1       2017-12-14          True
# ...               ...         ...          ...              ...           ...
# 19993           19836          40         3500       2017-03-14          True
# 19995            2463           2         3500       2017-04-25         False
# 19991            8562          33         3500       2017-08-08         False
# 19992            8416          74         3500       2017-02-16         False
# 19996           14870          22         3500       2017-01-11         False
#
# ...

# %%
newcustomer_df=pd.read_excel('C:/Users/ASUS/Desktop/KPMG.xlsx','NewCustomerList')

# %%
newcustomer_df.head()
# Out:
#   Note: The data and information in this document is reflective of a hypothetical situation and client. This document is to be used for KPMG Virtual Internship purposes only.   \
# 0                                         first_name
# 1                                            Chickie
# 2                                              Morly
# 3                                            Ardelis
# 4                                             Lucine
#
#   Unnamed: 1 Unnamed: 2                           Unnamed: 3  \
# 0  last_name     gender  past_3_years_bike_related_purchases
# 1    Brister       Male                                   86
# 2     Genery       Male                                   69
# 3  Forrester     Female                                   10
# 4      Stutt     Female                                   64
#
#             Unnamed: 4                  Unnamed: 5             Unnamed: 6  \
# 0                  DOB                   job_title  job_industry_category
# ...

# %%
newcustomer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 23 columns):
#  #   Column                                                                                                                                                                         Non-Null Count  Dtype
# ---  ------                                                                                                                                                                         --------------  -----
#  0   Note: The data and information in this document is reflective of a hypothetical situation and client. This document is to be used for KPMG Virtual Internship purposes only.   1001 non-null   object
#  1   Unnamed: 1                                                                                                                                                                     972 non-null    object
# ...

# %%
newcustomer_df.columns=newcustomer_df.iloc[0]
newcustomer_df
# Out:
# 0     first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0     first_name  last_name  gender  past_3_years_bike_related_purchases
# 1        Chickie    Brister    Male                                   86
# 2          Morly     Genery    Male                                   69
# 3        Ardelis  Forrester  Female                                   10
# 4         Lucine      Stutt  Female                                   64
# ...          ...        ...     ...                                  ...
# 996    Ferdinand  Romanetti    Male                                   60
# 997         Burk    Wortley    Male                                   22
# 998     Melloney      Temby  Female                                   17
# 999       Dickie    Cubbini    Male                                   30
# 1000       Sylas    Duffill    Male                                   56
#
# 0                     DOB                     job_title  \
# ...

# %%
newcustomer_df.drop(newcustomer_df.index[0],axis=0,inplace=True)
newcustomer_df
# Out:
# 0    first_name  last_name  gender past_3_years_bike_related_purchases  \
# 1       Chickie    Brister    Male                                  86
# 2         Morly     Genery    Male                                  69
# 3       Ardelis  Forrester  Female                                  10
# 4        Lucine      Stutt  Female                                  64
# 5       Melinda     Hadlee  Female                                  34
# ...         ...        ...     ...                                 ...
# 996   Ferdinand  Romanetti    Male                                  60
# 997        Burk    Wortley    Male                                  22
# 998    Melloney      Temby  Female                                  17
# 999      Dickie    Cubbini    Male                                  30
# 1000      Sylas    Duffill    Male                                  56
#
# 0                     DOB                     job_title job_industry_category  \
# ...

# %%
sns.distplot(df3['age'],hist=True,kde=True,rug=True,bins=40,fit=None,color='g',vertical=False)
plt.title('Age count')
plt.xlabel('Age')
plt.ylabel('count')
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_3600\2751492124.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df3['age'],hist=True,kde=True,rug=True,bins=40,fit=None,color='g',vertical=False)
# Text(0, 0.5, 'count')

# %%
sns.boxplot(x='count',y='standard_cost',data=df3,hue='owns_car')
plt.legend(loc='best')

# %%
sns.boxplot(x='age',y='list_price',hue='wealth_segment',data=df3)
plt.xlim(30,35)
plt.legend(loc='best')

# %%
sns.barplot(x='age',y='count',hue='online_order',data=df3)
plt.xlim(25,30)
plt.legend(loc='best')

# %%
corrmat=df3[['age','count']].corr()
sns.heatmap(corrmat,square=True)
# Out:
# <Axes: >

# %%
import datetime as dt
dt.datetime(transaction_df['transaction_date'][2].year,transaction_df['transaction_date'][2].month,1)
#get the first day of the month as cohort
# Out:
# datetime.datetime(2017, 5, 1, 0, 0)

# %%
def get_month(x):
    return dt.datetime(x.year,x.month,1)
df3['TransactionMonth']=df3['transaction_date'].apply(get_month)
df3
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               16423           9            1       2017-12-09          True
# 10               9785          72            1       2017-01-05         False
# 9               13424           2            1       2017-02-21         False
# 7               14486          23            1       2017-03-27         False
# 6               14931          31            1       2017-12-14          True
# ...               ...         ...          ...              ...           ...
# 19993           19836          40         3500       2017-03-14          True
# 19995            2463           2         3500       2017-04-25         False
# 19991            8562          33         3500       2017-08-08         False
# 19992            8416          74         3500       2017-02-16         False
# 19996           14870          22         3500       2017-01-11         False
#
# ...

# %%
def get_month(x):
    return dt.datetime(x.year,x.month,1)
transaction_df['TransactionMonth']=transaction_df['transaction_date'].apply(get_month)

# %%
transaction_df
# Out:
# 0      transaction_id  product_id  customer_id transaction_date  online_order  \
# 1                   1           2         2950       2017-02-25         False
# 2                   2           3         3120       2017-05-21          True
# 3                   3          37          402       2017-10-16         False
# 4                   4          88         3135       2017-08-31         False
# 5                   5          78          787       2017-10-01          True
# ...               ...         ...          ...              ...           ...
# 19996           19996          51         1018       2017-06-24          True
# 19997           19997          41          127       2017-11-09          True
# 19998           19998          87         2284       2017-04-14          True
# 19999           19999           6         2764       2017-07-03         False
# 20000           20000          11         1144       2017-09-22          True
#
# ...

# %%
transaction_df.groupby('customer_id')['TransactionMonth'].min()
# Out:
# customer_id
# 1      2017-01-01
# 2      2017-05-01
# 3      2017-02-01
# 4      2017-04-01
# 5      2017-03-01
#           ...
# 3497   2017-09-01
# 3498   2017-02-01
# 3499   2017-01-01
# 3500   2017-01-01
# 5034   2017-01-01
# Name: TransactionMonth, Length: 3494, dtype: datetime64[ns]

# %%
transaction_df.groupby('customer_id')['TransactionMonth'].transform('min')#保留每行
# Out:
# 1       2017-02-01
# 2       2017-01-01
# 3       2017-01-01
# 4       2017-02-01
# 5       2017-01-01
#            ...
# 19996   2017-01-01
# 19997   2017-01-01
# 19998   2017-04-01
# 19999   2017-02-01
# 20000   2017-03-01
# Name: TransactionMonth, Length: 20000, dtype: datetime64[ns]

# %%
transaction_df['CohortMonth']=transaction_df.groupby('customer_id')['TransactionMonth'].transform('min')
transaction_df.head()
# Out:
# 0  transaction_id  product_id  customer_id transaction_date  online_order  \
# 1               1           2         2950       2017-02-25         False
# 2               2           3         3120       2017-05-21          True
# 3               3          37          402       2017-10-16         False
# 4               4          88         3135       2017-08-31         False
# 5               5          78          787       2017-10-01          True
#
# 0 order_status           brand product_line product_class product_size  \
# 1     Approved           Solex     Standard        medium       medium
# 2     Approved   Trek Bicycles     Standard        medium        large
# 3     Approved      OHM Cycles     Standard           low       medium
# 4     Approved  Norco Bicycles     Standard        medium       medium
# 5     Approved  Giant Bicycles     Standard        medium        large
#
# 0  list_price  standard_cost  product_first_sold_date TransactionMonth  \
# ...

# %%
def get_date_int(df,column):
    year=df[column].dt.year
    month=df[column].dt.month
    day=df[column].dt.day
    return year,month,day
transaction_year,transaction_month,_=get_date_int(transaction_df,'TransactionMonth')
cohort_year,cohort_month,_=get_date_int(transaction_df,'CohortMonth')

# %%
years_diff = transaction_year-cohort_year
months_diff= transaction_month-cohort_month
transaction_df['CohortIndex']=years_diff*12+months_diff+1
transaction_df.head()
# Out:
# 0  transaction_id  product_id  customer_id transaction_date  online_order  \
# 1               1           2         2950       2017-02-25         False
# 2               2           3         3120       2017-05-21          True
# 3               3          37          402       2017-10-16         False
# 4               4          88         3135       2017-08-31         False
# 5               5          78          787       2017-10-01          True
#
# 0 order_status           brand product_line product_class product_size  \
# 1     Approved           Solex     Standard        medium       medium
# 2     Approved   Trek Bicycles     Standard        medium        large
# 3     Approved      OHM Cycles     Standard           low       medium
# 4     Approved  Norco Bicycles     Standard        medium       medium
# 5     Approved  Giant Bicycles     Standard        medium        large
#
# 0  list_price  standard_cost  product_first_sold_date TransactionMonth  \
# ...

# %%
df_48=transaction_df[(transaction_df['CohortMonth']=='2017-7-01')&(transaction_df['CohortIndex']==5)]

# %%
df_31=transaction_df[(transaction_df['CohortMonth']=='2017-7-01')&(transaction_df['CohortIndex']==6)]

# %%
df_48.merge(df_31,how='left',on='customer_id')
# Out:
# 0   transaction_id_x  product_id_x  customer_id transaction_date_x  \
# 0               1751            22         2730         2017-11-21
# 1               1751            22         2730         2017-11-21
# 2               1751            22         2730         2017-11-21
# 3               2161            98         2694         2017-11-22
# 4               2562            35         2514         2017-11-14
# 5               3036            27         2730         2017-11-21
# 6               3036            27         2730         2017-11-21
# 7               3036            27         2730         2017-11-21
# 8               3398            51         1809         2017-11-20
# 9               3992             1         3172         2017-11-05
# 10              4003             3         2893         2017-11-01
# 11              4142            41         2945         2017-11-11
# 12              4882            28          635         2017-11-21
# ...

# %%
cohort_data=transaction_df.groupby(['CohortMonth','CohortIndex']).nunique()['customer_id'].reset_index()
cohort_data.head()
# Out:
#   CohortMonth  CohortIndex  customer_id
# 0  2017-01-01            1         1354
# 1  2017-01-01            2          486
# 2  2017-01-01            3          508
# 3  2017-01-01            4          509
# 4  2017-01-01            5          502

# %%
cohort_data.pivot(index='CohortMonth',columns='CohortIndex',values='customer_id')
# Out:
# CohortIndex      1      2      3      4      5      6      7      8      9   \
# CohortMonth
# 2017-01-01   1354.0  486.0  508.0  509.0  502.0  483.0  518.0  529.0  500.0
# 2017-02-01    800.0  325.0  298.0  313.0  288.0  298.0  308.0  281.0  329.0
# 2017-03-01    484.0  167.0  174.0  167.0  182.0  184.0  172.0  212.0  189.0
# 2017-04-01    336.0  111.0  121.0  153.0  143.0  121.0  142.0  126.0  132.0
# 2017-05-01    210.0   85.0   81.0   87.0   71.0   74.0   73.0   81.0    NaN
# 2017-06-01    122.0   45.0   44.0   47.0   46.0   46.0   53.0    NaN    NaN
# 2017-07-01     77.0   26.0   29.0   32.0   37.0   24.0    NaN    NaN    NaN
# 2017-08-01     51.0   19.0   21.0   17.0   13.0    NaN    NaN    NaN    NaN
# 2017-09-01     23.0    7.0    7.0    9.0    NaN    NaN    NaN    NaN    NaN
# 2017-10-01     20.0    6.0    8.0    NaN    NaN    NaN    NaN    NaN    NaN
# 2017-11-01     13.0    5.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# ...

# %%
cohort_counts=cohort_data.pivot(index='CohortMonth',columns='CohortIndex',values='customer_id')
cohort_sizes=cohort_counts.iloc[:,0]
retention=cohort_counts.divide(cohort_sizes,axis=0)
retention2=retention.round(3)*100

# %%
plt.figure(figsize=(16,10))
plt.title('Average Standard Cost:Monthly Cohorts',fontsize=14)
sns.heatmap(retention2,annot=True,vmin=0.0,vmax=100,fmt='g')
plt.ylabel('Cohort Month')
plt.xlabel('Cohort Index')
plt.yticks(rotation='360')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[213], line 6
#       4 plt.ylabel('Cohort Month')
#       5 plt.xlabel('Cohort Index')
# ----> 6 plt.yticks(rotation='360')
#       7 plt.show()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\pyplot.py:1954, in yticks(ticks, labels, minor, **kwargs)
#    1952     labels = ax.get_yticklabels(minor=minor)
#    1953     for l in labels:
# -> 1954         l._internal_update(kwargs)
#    1955 else:
#    1956     labels = ax.set_yticklabels(labels, minor=minor, **kwargs)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\artist.py:1223, in Artist._internal_update(self, kwargs)
#    1216 def _internal_update(self, kwargs):
#    1217     """
#    1218     Update artist properties without prenormalizing them, but generating
#    1219     errors as if calling `set`.
#    1220
# ...

# %%
df3.head()
# Out:
#     transaction_id  product_id  customer_id transaction_date  online_order  \
# 0            16423           9            1       2017-12-09          True
# 10            9785          72            1       2017-01-05         False
# 9            13424           2            1       2017-02-21         False
# 7            14486          23            1       2017-03-27         False
# 6            14931          31            1       2017-12-14          True
#
#    order_status           brand product_line product_class product_size  ...  \
# 0      Approved      OHM Cycles         Road        medium       medium  ...
# 10     Approved  Norco Bicycles     Standard        medium       medium  ...
# 9      Approved           Solex     Standard        medium       medium  ...
# 7      Approved  Norco Bicycles     Mountain           low        small  ...
# 6      Approved  Giant Bicycles     Standard        medium       medium  ...
#
# ...

# %%
RFM_df=df3.groupby('customer_id').agg({'transaction_date':max,'count':max,'list_price':sum}).reset_index()

# %%
RFM_df.head()
# Out:
#    customer_id transaction_date  count  list_price
# 0            1       2017-12-23     11     9084.45
# 1            2       2017-08-24      3     4149.07
# 2            3       2017-09-19      8     9888.23
# 3            4       2017-06-18      2     1047.72
# 4            5       2017-12-14      6     5903.20

# %%
max_date=max(RFM_df['transaction_date'])
RFM_df['R']=(max_date-RFM_df['transaction_date']).dt.days

# %%
RFM_df.head()
# Out:
#    customer_id transaction_date  count  list_price    R
# 0            1       2017-12-23     11     9084.45    7
# 1            2       2017-08-24      3     4149.07  128
# 2            3       2017-09-19      8     9888.23  102
# 3            4       2017-06-18      2     1047.72  195
# 4            5       2017-12-14      6     5903.20   16

# %%
rfm_df=RFM_df[['customer_id','count','list_price','R']]
rfm_df.columns=['customer_id','F','M','R']
rfm_df
# Out:
#       customer_id   F        M    R
# 0               1  11  9084.45    7
# 1               2   3  4149.07  128
# 2               3   8  9888.23  102
# 3               4   2  1047.72  195
# 4               5   6  5903.20   16
# ...           ...  ..      ...  ...
# 3488         3496   4  4725.38  256
# 3489         3497   3  3744.07   52
# 3490         3498   6  5177.06  127
# 3491         3499   7  7673.48   51
# 3492         3500   6  4922.41  144
#
# [3493 rows x 4 columns]

# %%
r_med=np.median(rfm_df['R'])
f_med=np.median(rfm_df['F'])
m_med=np.median(rfm_df['M'])
r_med,f_med,m_med
# Out:
# (44.0, 6.0, 6029.25)

# %%
rfm_df.loc[(rfm_df['R']>=r_med)&(rfm_df['F']>=f_med)&(rfm_df['M']>=m_med),'tag']='重要价值用户-hhh'
rfm_df.loc[(rfm_df['R']>=r_med)&(rfm_df['F']<f_med)&(rfm_df['M']>=m_med),'tag']='重要发展用户-hlh'
rfm_df.loc[(rfm_df['R']<r_med)&(rfm_df['F']>=f_med)&(rfm_df['M']>=m_med),'tag']='重要保持用户-lhh'
rfm_df.loc[(rfm_df['R']<r_med)&(rfm_df['F']<f_med)&(rfm_df['M']>=m_med),'tag']='重要挽留用户-llh'
rfm_df.loc[(rfm_df['R']>=r_med)&(rfm_df['F']>=f_med)&(rfm_df['M']<m_med),'tag']='一般价值用户-hhl'
rfm_df.loc[(rfm_df['R']>=r_med)&(rfm_df['F']<f_med)&(rfm_df['M']<m_med),'tag']='一般发展用户-hll'
rfm_df.loc[(rfm_df['R']<r_med)&(rfm_df['F']>=f_med)&(rfm_df['M']<m_med),'tag']='一般保持用户-lhl'
rfm_df.loc[(rfm_df['R']<r_med)&(rfm_df['F']<f_med)&(rfm_df['M']<m_med),'tag']='一般挽留用户-lll'

# %%
rfm_df.head()
# Out:
#    customer_id   F        M    R         tag
# 0            1  11  9084.45    7  重要保持用户-lhh
# 1            2   3  4149.07  128  一般发展用户-hll
# 2            3   8  9888.23  102  重要价值用户-hhh
# 3            4   2  1047.72  195  一般发展用户-hll
# 4            5   6  5903.20   16  一般保持用户-lhl

# %%
df6=rfm_df['tag'].value_counts()
df6
# Out:
# tag
# 重要保持用户-lhh    901
# 一般发展用户-hll    890
# 重要价值用户-hhh    585
# 一般挽留用户-lll    560
# 一般保持用户-lhl    164
# 重要发展用户-hlh    146
# 一般价值用户-hhl    132
# 重要挽留用户-llh    115
# Name: count, dtype: int64

# %%
df4=df3.groupby('customer_id').agg({'age':max}).reset_index()

# %%
df4.head()
# Out:
#    customer_id   age
# 0            1  70.0
# 1            2  43.0
# 2            3  70.0
# 3            4  62.0
# 4            5  46.0

# %%
df5=rfm_df.merge(df4,how='inner',on='customer_id')

# %%
df5.head()
# Out:
#    customer_id   F        M    R         tag  count   age
# 0            1  11  9084.45    7  重要保持用户-lhh    NaN  70.0
# 1            2   3  4149.07  128  一般发展用户-hll    NaN  43.0
# 2            3   8  9888.23  102  重要价值用户-hhh    NaN  70.0
# 3            4   2  1047.72  195  一般发展用户-hll    NaN  62.0
# 4            5   6  5903.20   16  一般保持用户-lhl    NaN  46.0

# %%
df7=df5.merge(df6,how='inner',on='tag')

# %%
df7.head()
# Out:
#    customer_id   F         M   R         tag  count_x   age  count_y
# 0            1  11   9084.45   7  重要保持用户-lhh      NaN  70.0      901
# 1            8  10  12024.76  22  重要保持用户-lhh      NaN  61.0      901
# 2           10   6   7067.83  33  重要保持用户-lhh      NaN  35.0      901
# 3           13   7   7734.74  27  重要保持用户-lhh      NaN  69.0      901
# 4           23   7   8415.53  10  重要保持用户-lhh      NaN  29.0      901

# %%
sns.barplot(df7,x='tag',y='count_y')
# Out:
# <Axes: xlabel='tag', ylabel='count_y'>
# C:\ProgramData\anaconda3\Lib\site-packages\IPython\core\events.py:93: UserWarning: Glyph 37325 (\N{CJK UNIFIED IDEOGRAPH-91CD}) missing from current font.
#   func(*args, **kwargs)
# C:\ProgramData\anaconda3\Lib\site-packages\IPython\core\events.py:93: UserWarning: Glyph 35201 (\N{CJK UNIFIED IDEOGRAPH-8981}) missing from current font.
#   func(*args, **kwargs)
# C:\ProgramData\anaconda3\Lib\site-packages\IPython\core\events.py:93: UserWarning: Glyph 20445 (\N{CJK UNIFIED IDEOGRAPH-4FDD}) missing from current font.
#   func(*args, **kwargs)
# C:\ProgramData\anaconda3\Lib\site-packages\IPython\core\events.py:93: UserWarning: Glyph 25345 (\N{CJK UNIFIED IDEOGRAPH-6301}) missing from current font.
#   func(*args, **kwargs)
# C:\ProgramData\anaconda3\Lib\site-packages\IPython\core\events.py:93: UserWarning: Glyph 29992 (\N{CJK UNIFIED IDEOGRAPH-7528}) missing from current font.
#   func(*args, **kwargs)
# ...

# %%
sns.distplot(df7['M'],bins=40)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_3600\3011991962.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df7['M'],bins=40)
# <Axes: xlabel='M', ylabel='Density'>

# %%
df3.head()
# Out:
#     transaction_id  product_id  customer_id transaction_date  online_order  \
# 0            16423           9            1       2017-12-09          True
# 10            9785          72            1       2017-01-05         False
# 9            13424           2            1       2017-02-21         False
# 7            14486          23            1       2017-03-27         False
# 6            14931          31            1       2017-12-14          True
#
#    order_status           brand product_line product_class product_size  ...  \
# 0      Approved      OHM Cycles         Road        medium       medium  ...
# 10     Approved  Norco Bicycles     Standard        medium       medium  ...
# 9      Approved           Solex     Standard        medium       medium  ...
# 7      Approved  Norco Bicycles     Mountain           low        small  ...
# 6      Approved  Giant Bicycles     Standard        medium       medium  ...
#
# ...

# %%
dff=df3.groupby(['customer_id','job_title','job_industry_category','owns_car'])
dff

# %%
df8=df3[['customer_id','job_title','job_industry_category','owns_car']].drop_duplicates()

# %%
df8.head()
# Out:
#     customer_id            job_title job_industry_category owns_car
# 0             1  Executive Secretary                Health      Yes
# 10            1  Executive Secretary                Health      Yes
# 9             1  Executive Secretary                Health      Yes
# 7             1  Executive Secretary                Health      Yes
# 6             1  Executive Secretary                Health      Yes

# %%
df=df7.merge(df3,how='inner',on='customer_id')

# %%
df.head()
# Out:
#    customer_id   F        M  R         tag  count_x  age_x  count_y  \
# 0            1  11  9084.45  7  重要保持用户-lhh      NaN   70.0      901
# 1            1  11  9084.45  7  重要保持用户-lhh      NaN   70.0      901
# 2            1  11  9084.45  7  重要保持用户-lhh      NaN   70.0      901
# 3            1  11  9084.45  7  重要保持用户-lhh      NaN   70.0      901
# 4            1  11  9084.45  7  重要保持用户-lhh      NaN   70.0      901
#
#    transaction_id  product_id  ... age_y            job_title  \
# 0           16423           9  ...  70.0  Executive Secretary
# 1            9785          72  ...  70.0  Executive Secretary
# 2           13424           2  ...  70.0  Executive Secretary
# 3           14486          23  ...  70.0  Executive Secretary
# 4           14931          31  ...  70.0  Executive Secretary
#
#   job_industry_category wealth_segment deceased_indicator owns_car tenure  \
# 0                Health  Mass Customer                  N      Yes   11.0
# ...

# %%
sns.stripplot(df,x='tag',y='age_y',hue='gender')
# Out:
# <Axes: xlabel='tag', ylabel='age_y'>
# C:\ProgramData\anaconda3\Lib\site-packages\IPython\core\events.py:93: UserWarning: Glyph 37325 (\N{CJK UNIFIED IDEOGRAPH-91CD}) missing from current font.
#   func(*args, **kwargs)
# C:\ProgramData\anaconda3\Lib\site-packages\IPython\core\events.py:93: UserWarning: Glyph 35201 (\N{CJK UNIFIED IDEOGRAPH-8981}) missing from current font.
#   func(*args, **kwargs)
# C:\ProgramData\anaconda3\Lib\site-packages\IPython\core\events.py:93: UserWarning: Glyph 20445 (\N{CJK UNIFIED IDEOGRAPH-4FDD}) missing from current font.
#   func(*args, **kwargs)
# C:\ProgramData\anaconda3\Lib\site-packages\IPython\core\events.py:93: UserWarning: Glyph 25345 (\N{CJK UNIFIED IDEOGRAPH-6301}) missing from current font.
#   func(*args, **kwargs)
# C:\ProgramData\anaconda3\Lib\site-packages\IPython\core\events.py:93: UserWarning: Glyph 29992 (\N{CJK UNIFIED IDEOGRAPH-7528}) missing from current font.
#   func(*args, **kwargs)
# ...

# %%
sns.relplot(df,x='age_y',y='M',hue='owns_car',col='tag')
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: Glyph 37325 (\N{CJK UNIFIED IDEOGRAPH-91CD}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: Glyph 35201 (\N{CJK UNIFIED IDEOGRAPH-8981}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: Glyph 20445 (\N{CJK UNIFIED IDEOGRAPH-4FDD}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: Glyph 25345 (\N{CJK UNIFIED IDEOGRAPH-6301}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: Glyph 29992 (\N{CJK UNIFIED IDEOGRAPH-7528}) missing from current font.
# ...

# %%
sns.relplot(df,x='age_y',y='M',hue='tag',col='owns_car',row='job_industry_category')
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 37325 (\N{CJK UNIFIED IDEOGRAPH-91CD}) missing from current font.
#   fig.canvas.draw()
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 35201 (\N{CJK UNIFIED IDEOGRAPH-8981}) missing from current font.
#   fig.canvas.draw()
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 20445 (\N{CJK UNIFIED IDEOGRAPH-4FDD}) missing from current font.
#   fig.canvas.draw()
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 25345 (\N{CJK UNIFIED IDEOGRAPH-6301}) missing from current font.
#   fig.canvas.draw()
# ...

# %%
sns.relplot(df,x='age_y',y='M',hue='tag',col='job_industry_category')
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 37325 (\N{CJK UNIFIED IDEOGRAPH-91CD}) missing from current font.
#   fig.canvas.draw()
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 35201 (\N{CJK UNIFIED IDEOGRAPH-8981}) missing from current font.
#   fig.canvas.draw()
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 20445 (\N{CJK UNIFIED IDEOGRAPH-4FDD}) missing from current font.
#   fig.canvas.draw()
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 25345 (\N{CJK UNIFIED IDEOGRAPH-6301}) missing from current font.
#   fig.canvas.draw()
# ...

# %%
correlation=df[['age_x','count_y','M']].corr()

# %%
sns.heatmap(correlation,annot=True)
# Out:
# <Axes: >

# %%
df_tag.groupby(['tag','product_brand' , 'gender', '...')['transaction_id].count()
Ronciy Yang
11:29 AM
df_tag.groupby(['tag','product_brand' , 'gender', '...')['profit].mean()
df_tag.groupby(['tag','product_brand' , 'gender', '...')['profit].sum()
df_tag.groupby(['tag','product_brand' , 'own', '...')['profit].mean()
Ronciy Yang
11:30 AM
df_tag.groupby(['tag','product_brand' , 'wealth', '...')['profit].mean()
